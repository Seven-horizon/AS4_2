# %%
# Assignment A4B

This notebook demonstrates simple CSV data analysis using pandas.
A dataset is loaded, basic statistics are computed, and a chart is plotted.

# %%
import pandas as pd

FILE = "data/population.csv"
df = pd.read_csv(FILE)
df.head()
# Out:
#        City      Country  Population
# 0   Halifax       Canada      439819
# 1    Zurich  Switzerland      421878
# 2      Oslo       Norway      697010
# 3  Valencia        Spain      791413

# %%
import matplotlib.pyplot as plt

df.plot(kind="bar", x=df.columns[0], y=df.columns[2])
plt.show()
